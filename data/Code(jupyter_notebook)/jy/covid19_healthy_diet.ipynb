# %% [markdown]
# # 1. 기본 라이브러리 세팅

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # 1.1 데이터 파일과 column 살펴보기
#
#
#
# 1. Food_Supply_Kcal_Data.csv
#
# 각 나라의 사람들이 어떤 음식에서 에너지(kcal)를 섭취하는 지를 퍼센티지로 나타낸 데이터셋이다. 뒤쪽의 column들은 비만, 영양실조, 코로나 19 감염 사례 수를 전체 인구의 퍼센티지로 나타낸다.
#
# - country: 국가
# - 식품군 ex.Meat, Eggs, Fruits etc...
# - 건강 상태
#   Obesity: 비만
#   Undernourished: 영양실조
#   Confirmed: COVID 19 확진율
#   Deaths: COVID 19 사망율
#   Recovered: COVID 19 회복율
#   Active: COVID 19 환자 비율
#   Population: 인구 수
#   Unit
#
# 2. Fat_Supply_Quantity_Data.csv
#
# 각 나라의 사람들이 어떤 음식에서 지방을 섭취하는 지를 퍼센티지로 나타낸 데이터셋이다. 뒤쪽의 column들은 비만, 영양실조, 코로나 19 감염 사례 수를 전체 인구의 퍼센티지로 나타낸다.
#
# 3. Protein_Supply_Quantity_Data.csv
#
# 각 나라의 사람들이 어떤 음식에서 단백질을 섭취하는 지를 퍼센티지로 나타낸 데이터셋이다. 뒤쪽의 column들은 비만, 영양실조, 코로나 19 감염 사례 수를 전체 인구의 퍼센티지로 나타낸다.
#
# 4. Supply_Food_Data_Descriptions.csv
#
# 각 식품군에 어떤 식품이 포함되어 있는지를 알려준다.
#
# 5. Food_Supply_Quantity_kg_Data.csv
#
# 각 나라 별 인당 음식 섭취량(kg)을 퍼센티지로 나타낸 데이터셋이다. 뒤쪽의 column들은 비만, 영양실조, 코로나 19 감염 사례 수를 전체 인구의 퍼센티지로 나타낸다.

# %% [markdown]
# # 2. 데이터 살펴보기

# %%
path = './archive/'

food = pd.read_csv(path+'Food_Supply_Kcal_Data.csv')
fat = pd.read_csv(path+'Fat_Supply_Quantity_Data.csv')
protein = pd.read_csv(path+'Protein_Supply_Quantity_Data.csv')
desc = pd.read_csv(path+'Supply_Food_Data_Descriptions.csv')
intake = pd.read_csv(path+'Food_Supply_Quantity_kg_Data.csv')

# %%
food
# Out:
#                                 Country  Alcoholic Beverages  Animal Products  \
# 0                           Afghanistan               0.0000           4.7774
# 1                               Albania               0.9120          16.0930
# 2                               Algeria               0.0896           6.0326
# 3                                Angola               1.9388           4.6927
# 4                   Antigua and Barbuda               2.3041          15.3672
# ..                                  ...                  ...              ...
# 165  Venezuela (Bolivarian Republic of)               0.8454           7.2303
# 166                             Vietnam               0.7150          10.9806
# 167                               Yemen               0.0000           3.4667
# 168                              Zambia               1.1925           3.3043
# 169                            Zimbabwe               1.4269           3.9356
#
# ...

# %%
food.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170 entries, 0 to 169
# Data columns (total 32 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Country                       170 non-null    object
#  1   Alcoholic Beverages           170 non-null    float64
#  2   Animal Products               170 non-null    float64
#  3   Animal fats                   170 non-null    float64
#  4   Aquatic Products, Other       170 non-null    float64
#  5   Cereals - Excluding Beer      170 non-null    float64
#  6   Eggs                          170 non-null    float64
#  7   Fish, Seafood                 170 non-null    float64
#  8   Fruits - Excluding Wine       170 non-null    float64
#  9   Meat                          170 non-null    float64
#  10  Milk - Excluding Butter       170 non-null    float64
#  11  Miscellaneous                 170 non-null    float64
# ...

# %%
fat
# Out:
#                                 Country  Alcoholic Beverages  Animal Products  \
# 0                           Afghanistan               0.0000          21.6397
# 1                               Albania               0.0000          32.0002
# 2                               Algeria               0.0000          14.4175
# 3                                Angola               0.0000          15.3041
# 4                   Antigua and Barbuda               0.0000          27.7033
# ..                                  ...                  ...              ...
# 165  Venezuela (Bolivarian Republic of)               0.0000          16.3261
# 166                             Vietnam               0.0000          33.2484
# 167                               Yemen               0.0000          12.5401
# 168                              Zambia               0.0783           9.6005
# 169                            Zimbabwe               0.0000          10.3796
#
# ...

# %%
fat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170 entries, 0 to 169
# Data columns (total 32 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Country                       170 non-null    object
#  1   Alcoholic Beverages           170 non-null    float64
#  2   Animal Products               170 non-null    float64
#  3   Animal fats                   170 non-null    float64
#  4   Aquatic Products, Other       170 non-null    float64
#  5   Cereals - Excluding Beer      170 non-null    float64
#  6   Eggs                          170 non-null    float64
#  7   Fish, Seafood                 170 non-null    float64
#  8   Fruits - Excluding Wine       170 non-null    float64
#  9   Meat                          170 non-null    float64
#  10  Miscellaneous                 170 non-null    float64
#  11  Milk - Excluding Butter       170 non-null    float64
# ...

# %%
protein
# Out:
#                                 Country  Alcoholic Beverages  Animal Products  \
# 0                           Afghanistan               0.0000           9.7523
# 1                               Albania               0.1840          27.7469
# 2                               Algeria               0.0323          13.8360
# 3                                Angola               0.6285          15.2311
# 4                   Antigua and Barbuda               0.1535          33.1901
# ..                                  ...                  ...              ...
# 165  Venezuela (Bolivarian Republic of)               0.1955          22.5411
# 166                             Vietnam               0.1555          20.4466
# 167                               Yemen               0.0000          10.0122
# 168                              Zambia               0.4824           9.8925
# 169                            Zimbabwe               0.2929          11.3443
#
# ...

# %%
protein.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170 entries, 0 to 169
# Data columns (total 32 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Country                       170 non-null    object
#  1   Alcoholic Beverages           170 non-null    float64
#  2   Animal Products               170 non-null    float64
#  3   Animal fats                   170 non-null    float64
#  4   Aquatic Products, Other       170 non-null    float64
#  5   Cereals - Excluding Beer      170 non-null    float64
#  6   Eggs                          170 non-null    float64
#  7   Fish, Seafood                 170 non-null    float64
#  8   Fruits - Excluding Wine       170 non-null    float64
#  9   Meat                          170 non-null    float64
#  10  Milk - Excluding Butter       170 non-null    float64
#  11  Offals                        170 non-null    float64
# ...

# %%
desc
# Out:
#                   Categories  \
# 0        Alcoholic Beverages
# 1                Animal fats
# 2            Animal Products
# 3    Aquatic Products, Other
# 4   Cereals - Excluding Beer
# 5                       Eggs
# 6              Fish, Seafood
# 7    Fruits - Excluding Wine
# 8                       Meat
# 9    Milk - Excluding Butter
# 10             Miscellaneous
# 11                    Offals
# 12                  Oilcrops
# 13                    Pulses
# 14                    Spices
# 15             Starchy Roots
# 16                Stimulants
# 17        Sugar & Sweeteners
# 18               Sugar Crops
# 19                  Treenuts
# 20            Vegetable Oils
# 21                Vegetables
# 22          Vegetal Products
#
#                                                 Items
# 0   Alcohol, Non-Food; Beer; Beverages, Alcoholic;...
# 1   Butter, Ghee; Cream; Fats, Animals, Raw; Fish,...
# 2   Aquatic Animals, Others; Aquatic Plants; Bovin...
# ...

# %%
desc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Categories  23 non-null     object
#  1   Items       23 non-null     object
# dtypes: object(2)
# memory usage: 496.0+ bytes

# %%
intake
# Out:
#                                 Country  Alcoholic Beverages  Animal fats  \
# 0                           Afghanistan               0.0014       0.1973
# 1                               Albania               1.6719       0.1357
# 2                               Algeria               0.2711       0.0282
# 3                                Angola               5.8087       0.0560
# 4                   Antigua and Barbuda               3.5764       0.0087
# ..                                  ...                  ...          ...
# 165  Venezuela (Bolivarian Republic of)               2.5952       0.0403
# 166                             Vietnam               1.4591       0.1640
# 167                               Yemen               0.0364       0.0446
# 168                              Zambia               5.7360       0.0829
# 169                            Zimbabwe               4.0552       0.0755
#
#      Animal Products  Aquatic Products, Other  Cereals - Excluding Beer  \
# ...

# %%
intake.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170 entries, 0 to 169
# Data columns (total 32 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Country                       170 non-null    object
#  1   Alcoholic Beverages           170 non-null    float64
#  2   Animal fats                   170 non-null    float64
#  3   Animal Products               170 non-null    float64
#  4   Aquatic Products, Other       170 non-null    float64
#  5   Cereals - Excluding Beer      170 non-null    float64
#  6   Eggs                          170 non-null    float64
#  7   Fish, Seafood                 170 non-null    float64
#  8   Fruits - Excluding Wine       170 non-null    float64
#  9   Meat                          170 non-null    float64
#  10  Milk - Excluding Butter       170 non-null    float64
#  11  Miscellaneous                 170 non-null    float64
# ...

# %% [markdown]
# # 2.1 전처리

# %%
food_supply = food.drop('Unit (all except Population)', axis=1)
food_supply = food_supply.dropna()

protein_supply = protein.drop('Unit (all except Population)', axis=1)
protein_supply = protein_supply.dropna()
protein.head()
# Out:
#                Country  Alcoholic Beverages  Animal Products  Animal fats  \
# 0          Afghanistan               0.0000           9.7523       0.0277
# 1              Albania               0.1840          27.7469       0.0711
# 2              Algeria               0.0323          13.8360       0.0054
# 3               Angola               0.6285          15.2311       0.0277
# 4  Antigua and Barbuda               0.1535          33.1901       0.1289
#
#    Aquatic Products, Other  Cereals - Excluding Beer    Eggs  Fish, Seafood  \
# 0                      0.0                   35.9771  0.4067         0.0647
# 1                      0.0                   14.2331  1.8069         0.6274
# 2                      0.0                   26.5633  1.2916         0.6350
# 3                      0.0                   20.3882  0.1756         5.4436
# 4                      0.0                   10.5108  0.4850         8.2146
#
# ...

# %% [markdown]
# # 3. 비만율과 섭취하는 음식의 상관관계
#
# 가설: 비만율이 높은 나라가 비만율이 낮은 나라보다 영양소 섭취가 균일하지 못할 것이다.
#
# 전체 국가의 비만율의 평균을 구해 비만율이 높은 나라와 낮은 나라로 분류하여
# 비만율이 높은 나라와 낮은 나라의 평균 영양소 섭취량을 그래프로 그리기

# %%
high_obesity = food[food.Obesity > food['Obesity'].mean()]
low_obesity = food[food.Obesity <= food['Obesity'].mean()]

animal_features = ['Animal fats', 'Aquatic Products, Other', 'Eggs', 'Fish, Seafood', 'Meat',
                   'Milk - Excluding Butter', 'Offals']
vegetal_features = ['Cereals - Excluding Beer', 'Fruits - Excluding Wine', 'Miscellaneous', 'Oilcrops', 'Pulses',
                    'Spices', 'Starchy Roots', 'Stimulants', 'Sugar & Sweeteners', 'Sugar Crops', 'Treenuts',
                    'Vegetable Oils', 'Vegetables']

# %%
high_animal = high_obesity[animal_features].sum(axis=1).mean()
low_animal = low_obesity[animal_features].sum(axis=1).mean()

# %%
high_vegetal = high_obesity[vegetal_features].sum(axis=1).mean()
low_vegetal = low_obesity[vegetal_features].sum(axis=1).mean()

# %%
ratio = [high_vegetal, high_animal]
labels = ['Plant-based food', 'Animal-based food']

plt.pie(ratio, labels=labels, autopct='%.1f%%', counterclock=False, colors = ['#FD5D5D', '#C0EDA6'])
plt.title("Food intake in high-obesity countries")
# plt.show()

plt.savefig("high-obesity.png")

# %%
ratio = [low_vegetal, low_animal]
labels = ['Plant-based food', 'Animal-based food']

plt.pie(ratio, labels=labels, autopct='%.1f%%', counterclock=False, colors = ['#FD5D5D', '#C0EDA6'])
plt.title("Food intake in low-obesity countries")
# plt.show()

plt.savefig("low-obesity.png")

# %% [markdown]
# # 3.1. 동물성 단백질, 식물성 단백질 섭취량과 비만의 상관 관계
#
# 가설: 비만율이 높은 국가의 동물성 단백질 섭취량이 비만율이 낮은 국가보다 높을 것이다.
#
# 비만율이 높은 국가의 동물성 단백질, 식물성 단백질 섭취량과 비만율이 낮은 국가의 동물성 단백질, 식물성 단백질 섭취량 비교
#
# 결과: 비만율이 높은 국가는 동물성 단백질과 식물성 단백질의 섭취량이 거의 반반이고, 비만율이 낮은 국가는 식물성 단백질 섭취량이 동물성 단백질 섭취량보다 높다.

# %%
protein_high_obesity = protein[protein.Obesity > protein['Obesity'].mean()]
protein_low_obesity = protein[protein.Obesity <= protein['Obesity'].mean()]

p_high_animal = protein_high_obesity[animal_features].sum(axis=1).mean()
p_low_animal = protein_low_obesity[animal_features].sum(axis=1).mean()

p_high_vegetal = protein_high_obesity[vegetal_features].sum(axis=1).mean()
p_low_vegetal = protein_low_obesity[vegetal_features].sum(axis=1).mean()

# %%
ratio = [p_high_vegetal, p_high_animal]
labels = ['Plant-based food', 'Animal-based food']

plt.pie(ratio, labels=labels, autopct='%.1f%%', counterclock=False, colors = ['#FD5D5D', '#C0EDA6'])
plt.title("Protein intake in high-obesity countries")

plt.savefig("high-obesity_protein.png", dpi=100)

# %%
ratio = [p_low_vegetal, p_low_animal]
labels = ['Plant-based food', 'Animal-based food']

plt.pie(ratio, labels=labels, autopct='%.1f%%', counterclock=False, colors = ['#FD5D5D', '#C0EDA6'])
plt.title("Protein intake in low-obesity countries")

plt.savefig("low-obesity_protein.png", dpi=100)

# %%
korea = protein[protein["Country"] == "Korea, South"]

korea_animal = korea[animal_features].sum(axis=1)
korea_vegetal = korea[vegetal_features].sum(axis=1)

korea_vegetal
# Out:
# 82    23.6342
# dtype: float64

# %%
len(high_obesity)
# Out:
# 101

# %%
len(low_obesity)
# Out:
# 66

# %%
sns.scatterplot(
    protein[animal_features].sum(axis=1),
    protein[vegetal_features].sum(axis=1),
    size=protein["Obesity"], hue=protein["Obesity"], sizes=(1,200))

plt.xlabel("animal-based protein")
plt.ylabel("plant-based protein")

plt.grid()
# Out:
# C:\Users\juyoung\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
protein[animal_features].sum(axis=1)
# Out:
# 0       9.7522
# 1      27.7470
# 2      13.8307
# 3      15.2310
# 4      33.1838
#         ...
# 165    22.5499
# 166    20.4466
# 167    10.0215
# 168     9.8924
# 169    11.3542
# Length: 170, dtype: float64

# %%
protein[vegetal_features].sum(axis=1)
# Out:
# 0      40.2478
# 1      22.0670
# 2      36.1318
# 3      34.1311
# 4      16.6564
#         ...
# 165    27.2590
# 166    29.3896
# 167    39.9831
# 168    39.6208
# 169    38.3579
# Length: 170, dtype: float64

# %%
protein["Obesity"]
# Out:
# 0       4.5
# 1      22.3
# 2      26.6
# 3       6.8
# 4      19.1
#        ...
# 165    25.2
# 166     2.1
# 167    14.1
# 168     6.5
# 169    12.3
# Name: Obesity, Length: 170, dtype: float64
