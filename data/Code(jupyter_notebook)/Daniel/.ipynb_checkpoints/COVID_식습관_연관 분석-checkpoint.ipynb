# %%
#pip install plotly

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
food = pd.read_csv('../../Kaggle_DB/Daniel/Food_Supply_kcal_Data.csv')
#desc = pd.read_csv('Supply_Food_Data_Descriptions.csv')

# %%
food = food.fillna(0)
food.head()
# Out:
#                Country  Alcoholic Beverages  Animal Products  Animal fats  \
# 0          Afghanistan               0.0000           4.7774       0.8504
# 1              Albania               0.9120          16.0930       1.0591
# 2              Algeria               0.0896           6.0326       0.1941
# 3               Angola               1.9388           4.6927       0.2644
# 4  Antigua and Barbuda               2.3041          15.3672       1.5429
#
#    Aquatic Products, Other  Cereals - Excluding Beer    Eggs  Fish, Seafood  \
# 0                      0.0                   37.1186  0.1501         0.0000
# 1                      0.0                   16.2107  0.8091         0.1471
# 2                      0.0                   25.0112  0.4181         0.1195
# 3                      0.0                   18.3521  0.0441         0.8372
# 4                      0.0                   13.7215  0.2057         1.7280
#
# ...

# %%
food_corr=food.corr()
fig,ax = plt.subplots(figsize=(20,15))
mask = np.zeros_like(food_corr,dtype=bool)
mask[np.triu_indices_from(mask)] = True

sns.heatmap(food_corr, 
            cmap = 'RdYlBu_r', 
            annot = True,   # 실제 값을 표시한다
            mask=mask,      # 표시하지 않을 마스크 부분을 지정한다
            linewidths=.5,  # 경계면 실선으로 구분하기
            cbar_kws={"shrink": 0.5},# 컬러바 크기 절반으로 줄이기
            vmin = -1,vmax = 1   # 컬러바 범위 -1 ~ 1
           )
plt.show()

# %%
(food_corr.loc['Obesity'].iloc[:-6].sort_values()*100).plot.bar( rot=45,figsize=(20,5)).to_json
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-afaa301b897a> in <module>
# ----> 1 (food_corr.loc['Obesity'].iloc[:-6].sort_values()*100).plot.bar( rot=45,figsize=(20,5)).to_json
#
# AttributeError: 'AxesSubplot' object has no attribute 'to_json'
